# %%
import os
import numpy as np
import pandas as pd
from scipy import interpolate
from scipy.signal import resample

# %%
SAMPLE_RATE = 128  # fs
SAMPLE_LEN = 128   # T

# %%
# root dir
root = 'TDBrain\derivatives'
# participants file path
ptc_path = os.path.join(root, 'TDBRAIN_participants_V2.tsv')
ptc = pd.read_csv(ptc_path, sep='\t')
ptc
# Out:
#      participants_ID     DISC/REP   indication formal_status      Dataset  \
# 0       sub-19681349  REPLICATION  REPLICATION   REPLICATION  REPLICATION
# 1       sub-19681385  REPLICATION  REPLICATION   REPLICATION  REPLICATION
# 2       sub-19684666  REPLICATION  REPLICATION   REPLICATION  REPLICATION
# 3       sub-19686324  REPLICATION  REPLICATION   REPLICATION  REPLICATION
# 4       sub-19687321  REPLICATION  REPLICATION   REPLICATION  REPLICATION
# ...              ...          ...          ...           ...          ...
# 1345    sub-88078837    DISCOVERY     INSOMNIA      INSOMNIA          NaN
# 1346    sub-88079017    DISCOVERY     INSOMNIA      INSOMNIA          NaN
# 1347             NaN          NaN          NaN           NaN          NaN
# 1348             NaN          NaN          NaN           NaN          NaN
# 1349             NaN          NaN          NaN           NaN          NaN
#
#      Consent   sessSeason     sessTime    Responder     Remitter  ...  \
# 0        YES  REPLICATION  REPLICATION  REPLICATION  REPLICATION  ...
# 1        YES  REPLICATION  REPLICATION  REPLICATION  REPLICATION  ...
# 2        YES  REPLICATION  REPLICATION  REPLICATION  REPLICATION  ...
# 3        YES  REPLICATION  REPLICATION  REPLICATION  REPLICATION  ...
# 4        YES  REPLICATION  REPLICATION  REPLICATION  REPLICATION  ...
# ...      ...          ...          ...          ...          ...  ...
# 1345     YES       winter          NaN          NaN          NaN  ...
# 1346     YES       winter          NaN          NaN          NaN  ...
# 1347     NaN          NaN          NaN          NaN          NaN  ...
# 1348     NaN          NaN          NaN          NaN          NaN  ...
# 1349     NaN          NaN          NaN          NaN          NaN  ...
#
#          BDI_post  rTMS PROTOCOL  ADHD_pre_Hyp_leading  ADHD_pre_Att_leading  \
# 0     REPLICATION              2           REPLICATION           REPLICATION
# 1     REPLICATION              1           REPLICATION           REPLICATION
# 2     REPLICATION              1           REPLICATION           REPLICATION
# 3     REPLICATION              2           REPLICATION           REPLICATION
# 4     REPLICATION              3           REPLICATION           REPLICATION
# ...           ...            ...                   ...                   ...
# 1345          NaN            NaN                   NaN                   NaN
# 1346          NaN            NaN                   NaN                   NaN
# 1347          NaN            NaN                   NaN                   NaN
# 1348          NaN            NaN                   NaN                   NaN
# 1349          NaN            NaN                   NaN                   NaN
#
#       ADHD_post_Att_leading  ADHD_post_Hyp_leading  NF Protocol    YBOCS_pre  \
# 0               REPLICATION            REPLICATION  REPLICATION  REPLICATION
# 1               REPLICATION            REPLICATION  REPLICATION  REPLICATION
# 2               REPLICATION            REPLICATION  REPLICATION  REPLICATION
# 3               REPLICATION            REPLICATION  REPLICATION  REPLICATION
# 4               REPLICATION            REPLICATION  REPLICATION  REPLICATION
# ...                     ...                    ...          ...          ...
# 1345                    NaN                    NaN          NaN          NaN
# 1346                    NaN                    NaN          NaN          NaN
# 1347                    NaN                    NaN          NaN          NaN
# 1348                    NaN                    NaN          NaN          NaN
# 1349                    NaN                    NaN          NaN          NaN
#
#        YBOCS_post Unnamed: 110
# 0     REPLICATION          NaN
# 1     REPLICATION          NaN
# 2     REPLICATION          NaN
# 3     REPLICATION          NaN
# 4     REPLICATION          NaN
# ...           ...          ...
# 1345          NaN          NaN
# 1346          NaN          NaN
# 1347          NaN          NaN
# 1348          NaN          NaN
# 1349          NaN          NaN
#
# [1350 rows x 111 columns]

# %% [markdown]
# ## Labels

# %%
# delete invalid participants and the participants with replication indication(nan, replication)
# As described in their paper, the replication data is used for validation and test for the model. 
# You can contact the corresponding author of the TDBrain paper to verify the accuracy of the model about the replication data.
ptc = ptc[~(ptc['participants_ID'].isna())]
ptc = ptc[~(ptc['indication'].isna())]
ptc = ptc[~(ptc['indication']=='REPLICATION')]
# capitalize the indication uniformly
ptc['indication'] = ptc['indication'].str.upper()
# remove invalid space placeholder of disease label
ptc['indication'] = ptc['indication'].str.strip()
ptc
# Out:
#      participants_ID   DISC/REP indication formal_status Dataset Consent  \
# 120     sub-87963457  DISCOVERY    BURNOUT       BURNOUT     NaN     YES
# 121     sub-87963593  DISCOVERY    BURNOUT       BURNOUT     NaN     YES
# 122     sub-87963725  DISCOVERY        SMC       UNKNOWN     NaN     YES
# 123     sub-87963769  DISCOVERY        SMC       UNKNOWN     NaN     YES
# 124     sub-87964717  DISCOVERY        SMC       UNKNOWN     NaN     YES
# ...              ...        ...        ...           ...     ...     ...
# 1342    sub-88078657  DISCOVERY   INSOMNIA      INSOMNIA     NaN     YES
# 1343    sub-88078749  DISCOVERY   INSOMNIA      INSOMNIA     NaN     YES
# 1344    sub-88078793  DISCOVERY   INSOMNIA      INSOMNIA     NaN     YES
# 1345    sub-88078837  DISCOVERY   INSOMNIA      INSOMNIA     NaN     YES
# 1346    sub-88079017  DISCOVERY   INSOMNIA      INSOMNIA     NaN     YES
#
#      sessSeason   sessTime Responder Remitter  ... BDI_post  rTMS PROTOCOL  \
# 120      spring  afternoon       NaN      NaN  ...      NaN            NaN
# 121      spring    morning       NaN      NaN  ...      NaN            NaN
# 122      summer  afternoon       NaN      NaN  ...      NaN            NaN
# 123      summer  afternoon       NaN      NaN  ...      NaN            NaN
# 124      summer  afternoon       NaN      NaN  ...      NaN            NaN
# ...         ...        ...       ...      ...  ...      ...            ...
# 1342       fall        NaN       NaN      NaN  ...      NaN            NaN
# 1343     winter        NaN       NaN      NaN  ...      NaN            NaN
# 1344     winter        NaN       NaN      NaN  ...      NaN            NaN
# 1345     winter        NaN       NaN      NaN  ...      NaN            NaN
# 1346     winter        NaN       NaN      NaN  ...      NaN            NaN
#
#       ADHD_pre_Hyp_leading  ADHD_pre_Att_leading  ADHD_post_Att_leading  \
# 120                    NaN                   NaN                    NaN
# 121                    NaN                   NaN                    NaN
# 122                    NaN                   NaN                    NaN
# 123                    NaN                   NaN                    NaN
# 124                    NaN                   NaN                    NaN
# ...                    ...                   ...                    ...
# 1342                   NaN                   NaN                    NaN
# 1343                   NaN                   NaN                    NaN
# 1344                   NaN                   NaN                    NaN
# 1345                   NaN                   NaN                    NaN
# 1346                   NaN                   NaN                    NaN
#
#       ADHD_post_Hyp_leading NF Protocol YBOCS_pre YBOCS_post Unnamed: 110
# 120                     NaN         NaN       NaN        NaN          NaN
# 121                     NaN         NaN       NaN        NaN          NaN
# 122                     NaN         NaN       NaN        NaN          NaN
# 123                     NaN         NaN       NaN        NaN          NaN
# 124                     NaN         NaN       NaN        NaN          NaN
# ...                     ...         ...       ...        ...          ...
# 1342                    NaN         NaN       NaN        NaN          NaN
# 1343                    NaN         NaN       NaN        NaN          NaN
# 1344                    NaN         NaN       NaN        NaN          NaN
# 1345                    NaN         NaN       NaN        NaN          NaN
# 1346                    NaN         NaN       NaN        NaN          NaN
#
# [968 rows x 111 columns]

# %%
# Get duplicate values of participants_id
l = ptc.drop_duplicates(['participants_ID'],keep=False)['participants_ID'].to_list()
dup_ptc = ptc[~(ptc['participants_ID'].isin(l))]
dup_ptc
# Out:
#     participants_ID   DISC/REP         indication formal_status Dataset  \
# 124    sub-87964717  DISCOVERY                SMC       UNKNOWN     NaN
# 125    sub-87964717  DISCOVERY                SMC       UNKNOWN     NaN
# 131    sub-87966293  DISCOVERY                SMC       UNKNOWN     NaN
# 132    sub-87966293  DISCOVERY                SMC       UNKNOWN     NaN
# 133    sub-87966293  DISCOVERY                SMC       UNKNOWN     NaN
# ..              ...        ...                ...           ...     ...
# 958    sub-88047289  DISCOVERY  DEPERSONALIZATION       UNKNOWN     NaN
# 962    sub-88047649  DISCOVERY                OCD           OCD     OCD
# 963    sub-88047649  DISCOVERY                OCD           OCD     OCD
# 972    sub-88048193  DISCOVERY                OCD           OCD     OCD
# 973    sub-88048193  DISCOVERY                OCD           OCD     OCD
#
#     Consent sessSeason   sessTime Responder Remitter  ... BDI_post  \
# 124     YES     summer  afternoon       NaN      NaN  ...      NaN
# 125     YES     summer        NaN       NaN      NaN  ...      NaN
# 131     YES       fall  afternoon       NaN      NaN  ...      NaN
# 132     YES     winter  afternoon       NaN      NaN  ...      NaN
# 133     YES     spring    morning       NaN      NaN  ...      NaN
# ..      ...        ...        ...       ...      ...  ...      ...
# 958     YES     summer        NaN       NaN      NaN  ...      NaN
# 962     YES     summer        NaN         1        1  ...        6
# 963     YES     summer        NaN         1        1  ...        6
# 972     YES     summer        NaN         1        0  ...        0
# 973     YES     winter        NaN         1        0  ...        0
#
#      rTMS PROTOCOL  ADHD_pre_Hyp_leading  ADHD_pre_Att_leading  \
# 124            NaN                   NaN                   NaN
# 125            NaN                   NaN                   NaN
# 131            NaN                   NaN                   NaN
# 132            NaN                   NaN                   NaN
# 133            NaN                   NaN                   NaN
# ..             ...                   ...                   ...
# 958            NaN                   NaN                   NaN
# 962              7                   NaN                   NaN
# 963              7                   NaN                   NaN
# 972              7                   NaN                   NaN
# 973              7                   NaN                   NaN
#
#      ADHD_post_Att_leading  ADHD_post_Hyp_leading NF Protocol YBOCS_pre  \
# 124                    NaN                    NaN         NaN       NaN
# 125                    NaN                    NaN         NaN       NaN
# 131                    NaN                    NaN         NaN       NaN
# 132                    NaN                    NaN         NaN       NaN
# 133                    NaN                    NaN         NaN       NaN
# ..                     ...                    ...         ...       ...
# 958                    NaN                    NaN         NaN       NaN
# 962                    NaN                    NaN         NaN        23
# 963                    NaN                    NaN         NaN        23
# 972                    NaN                    NaN         NaN        22
# 973                    NaN                    NaN         NaN        22
#
#     YBOCS_post Unnamed: 110
# 124        NaN          NaN
# 125        NaN          NaN
# 131        NaN          NaN
# 132        NaN          NaN
# 133        NaN          NaN
# ..         ...          ...
# 958        NaN          NaN
# 962         12          NaN
# 963         12          NaN
# 972         13          NaN
# 973         13          NaN
#
# [110 rows x 111 columns]

# %%
# Test if the same participant has different indications for different sessions
for i in range(len(dup_ptc)):
    temp = dup_ptc[dup_ptc['participants_ID']==dup_ptc['participants_ID'].iloc[i]].drop_duplicates(['indication'])
    if len(temp)!=1:
        print('The different sessions in the same participant may have different indications!')

# %%
# Drop duplicate participants
ptc = ptc.drop_duplicates(['participants_ID'])
ptc
# Out:
#      participants_ID   DISC/REP indication formal_status Dataset Consent  \
# 120     sub-87963457  DISCOVERY    BURNOUT       BURNOUT     NaN     YES
# 121     sub-87963593  DISCOVERY    BURNOUT       BURNOUT     NaN     YES
# 122     sub-87963725  DISCOVERY        SMC       UNKNOWN     NaN     YES
# 123     sub-87963769  DISCOVERY        SMC       UNKNOWN     NaN     YES
# 124     sub-87964717  DISCOVERY        SMC       UNKNOWN     NaN     YES
# ...              ...        ...        ...           ...     ...     ...
# 1342    sub-88078657  DISCOVERY   INSOMNIA      INSOMNIA     NaN     YES
# 1343    sub-88078749  DISCOVERY   INSOMNIA      INSOMNIA     NaN     YES
# 1344    sub-88078793  DISCOVERY   INSOMNIA      INSOMNIA     NaN     YES
# 1345    sub-88078837  DISCOVERY   INSOMNIA      INSOMNIA     NaN     YES
# 1346    sub-88079017  DISCOVERY   INSOMNIA      INSOMNIA     NaN     YES
#
#      sessSeason   sessTime Responder Remitter  ... BDI_post  rTMS PROTOCOL  \
# 120      spring  afternoon       NaN      NaN  ...      NaN            NaN
# 121      spring    morning       NaN      NaN  ...      NaN            NaN
# 122      summer  afternoon       NaN      NaN  ...      NaN            NaN
# 123      summer  afternoon       NaN      NaN  ...      NaN            NaN
# 124      summer  afternoon       NaN      NaN  ...      NaN            NaN
# ...         ...        ...       ...      ...  ...      ...            ...
# 1342       fall        NaN       NaN      NaN  ...      NaN            NaN
# 1343     winter        NaN       NaN      NaN  ...      NaN            NaN
# 1344     winter        NaN       NaN      NaN  ...      NaN            NaN
# 1345     winter        NaN       NaN      NaN  ...      NaN            NaN
# 1346     winter        NaN       NaN      NaN  ...      NaN            NaN
#
#       ADHD_pre_Hyp_leading  ADHD_pre_Att_leading  ADHD_post_Att_leading  \
# 120                    NaN                   NaN                    NaN
# 121                    NaN                   NaN                    NaN
# 122                    NaN                   NaN                    NaN
# 123                    NaN                   NaN                    NaN
# 124                    NaN                   NaN                    NaN
# ...                    ...                   ...                    ...
# 1342                   NaN                   NaN                    NaN
# 1343                   NaN                   NaN                    NaN
# 1344                   NaN                   NaN                    NaN
# 1345                   NaN                   NaN                    NaN
# 1346                   NaN                   NaN                    NaN
#
#       ADHD_post_Hyp_leading NF Protocol YBOCS_pre YBOCS_post Unnamed: 110
# 120                     NaN         NaN       NaN        NaN          NaN
# 121                     NaN         NaN       NaN        NaN          NaN
# 122                     NaN         NaN       NaN        NaN          NaN
# 123                     NaN         NaN       NaN        NaN          NaN
# 124                     NaN         NaN       NaN        NaN          NaN
# ...                     ...         ...       ...        ...          ...
# 1342                    NaN         NaN       NaN        NaN          NaN
# 1343                    NaN         NaN       NaN        NaN          NaN
# 1344                    NaN         NaN       NaN        NaN          NaN
# 1345                    NaN         NaN       NaN        NaN          NaN
# 1346                    NaN         NaN       NaN        NaN          NaN
#
# [911 rows x 111 columns]

# %%
# EEG data preprocessing

# all disease mapping
all_dise_dict = {}
ls_ind = list(ptc['indication'].unique())
for i in range(len(ls_ind)):
    all_dise_dict[ls_ind[i]] = i
print(all_dise_dict)
    
ptc['indication_id'] = ptc['indication'].map(all_dise_dict)
ptc
# Out:
# {'BURNOUT': 0, 'SMC': 1, 'HEALTHY': 2, 'DYSLEXIA': 3, 'CHRONIC PAIN': 4, 'MDD': 5, 'ADHD': 6, 'ADHD/ASPERGER': 7, 'PDD NOS/DYSLEXIA': 8, 'PDD NOS': 9, 'WHIPLASH': 10, 'ANXIETY': 11, 'ADHD/DYSLEXIA': 12, 'ASD': 13, 'TINNITUS': 14, 'OCD': 15, 'PANIC': 16, 'MDD/ANXIETY': 17, 'MIGRAINE': 18, 'PDD NOS/ANXIETY': 19, 'PARKINSON': 20, 'BIPOLAR': 21, 'MDD/BIPOLAR': 22, 'DYSPRAXIA': 23, 'TINNITUS/MDD': 24, 'ADHD/ASD/ANXIETY': 25, 'MDD/ADHD': 26, 'ADHD/PDD NOS': 27, 'ASPERGER': 28, 'ADHD/EPILEPSY': 29, 'MDD/PAIN': 30, 'PDD NOS/GTS': 31, 'PDD NOS/ADHD': 32, 'PDD NOS/ASD': 33, 'TBI': 34, 'ADHD/ANXIETY': 35, 'ADHD/DYSLEXIA/DYSCALCULIA': 36, 'ADHD/MDD': 37, 'MDD/PANIC': 38, 'DEPERSONALIZATION': 39, 'MDD/TRAUMA': 40, 'PTSD/ADHD': 41, 'OCD/DPS': 42, 'MDD/OCD': 43, 'MDD/TUMOR': 44, 'ADHD/GTS': 45, 'OCD/MDD': 46, 'CONVERSION DX': 47, 'ASD/ASPERGER': 48, 'MDD/ADHD/LYME': 49, 'ADHD/OCD': 50, 'MSA-C': 51, 'OCD/ASD': 52, 'STROKE/PAIN': 53, 'STROKE': 54, 'MDD/OCD/ADHD': 55, 'EPILEPSY/OCD': 56, 'INSOMNIA': 57, 'MDD/ADHD/ANOREXIA': 58, 'MDD/ANXIETY/TINNITUS': 59}
# C:\Users\24700\AppData\Local\Temp\ipykernel_45140\3990244584.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ptc['indication_id'] = ptc['indication'].map(all_dise_dict)
#      participants_ID   DISC/REP indication formal_status Dataset Consent  \
# 120     sub-87963457  DISCOVERY    BURNOUT       BURNOUT     NaN     YES
# 121     sub-87963593  DISCOVERY    BURNOUT       BURNOUT     NaN     YES
# 122     sub-87963725  DISCOVERY        SMC       UNKNOWN     NaN     YES
# 123     sub-87963769  DISCOVERY        SMC       UNKNOWN     NaN     YES
# 124     sub-87964717  DISCOVERY        SMC       UNKNOWN     NaN     YES
# ...              ...        ...        ...           ...     ...     ...
# 1342    sub-88078657  DISCOVERY   INSOMNIA      INSOMNIA     NaN     YES
# 1343    sub-88078749  DISCOVERY   INSOMNIA      INSOMNIA     NaN     YES
# 1344    sub-88078793  DISCOVERY   INSOMNIA      INSOMNIA     NaN     YES
# 1345    sub-88078837  DISCOVERY   INSOMNIA      INSOMNIA     NaN     YES
# 1346    sub-88079017  DISCOVERY   INSOMNIA      INSOMNIA     NaN     YES
#
#      sessSeason   sessTime Responder Remitter  ... rTMS PROTOCOL  \
# 120      spring  afternoon       NaN      NaN  ...           NaN
# 121      spring    morning       NaN      NaN  ...           NaN
# 122      summer  afternoon       NaN      NaN  ...           NaN
# 123      summer  afternoon       NaN      NaN  ...           NaN
# 124      summer  afternoon       NaN      NaN  ...           NaN
# ...         ...        ...       ...      ...  ...           ...
# 1342       fall        NaN       NaN      NaN  ...           NaN
# 1343     winter        NaN       NaN      NaN  ...           NaN
# 1344     winter        NaN       NaN      NaN  ...           NaN
# 1345     winter        NaN       NaN      NaN  ...           NaN
# 1346     winter        NaN       NaN      NaN  ...           NaN
#
#       ADHD_pre_Hyp_leading  ADHD_pre_Att_leading  ADHD_post_Att_leading  \
# 120                    NaN                   NaN                    NaN
# 121                    NaN                   NaN                    NaN
# 122                    NaN                   NaN                    NaN
# 123                    NaN                   NaN                    NaN
# 124                    NaN                   NaN                    NaN
# ...                    ...                   ...                    ...
# 1342                   NaN                   NaN                    NaN
# 1343                   NaN                   NaN                    NaN
# 1344                   NaN                   NaN                    NaN
# 1345                   NaN                   NaN                    NaN
# 1346                   NaN                   NaN                    NaN
#
#       ADHD_post_Hyp_leading  NF Protocol YBOCS_pre YBOCS_post Unnamed: 110  \
# 120                     NaN          NaN       NaN        NaN          NaN
# 121                     NaN          NaN       NaN        NaN          NaN
# 122                     NaN          NaN       NaN        NaN          NaN
# 123                     NaN          NaN       NaN        NaN          NaN
# 124                     NaN          NaN       NaN        NaN          NaN
# ...                     ...          ...       ...        ...          ...
# 1342                    NaN          NaN       NaN        NaN          NaN
# 1343                    NaN          NaN       NaN        NaN          NaN
# 1344                    NaN          NaN       NaN        NaN          NaN
# 1345                    NaN          NaN       NaN        NaN          NaN
# 1346                    NaN          NaN       NaN        NaN          NaN
#
#      indication_id
# 120              0
# 121              0
# 122              1
# 123              1
# 124              1
# ...            ...
# 1342            57
# 1343            57
# 1344            57
# 1345            57
# 1346            57
#
# [911 rows x 112 columns]

# %%
"""# filter subjects with PARKINSON and healthy indication
# 25 PARKINSON & 47 healthy 
ptc = ptc[((ptc['indication_id']==20)|(ptc['indication_id']==2))]
ptc['is_parkinson'] = 0
ptc['is_parkinson'][ptc['indication_id']==20] = 1
ptc"""
# Out:
# "# filter subjects with PARKINSON and healthy indication\n# 25 PARKINSON & 47 healthy \nptc = ptc[((ptc['indication_id']==20)|(ptc['indication_id']==2))]\nptc['is_parkinson'] = 0\nptc['is_parkinson'][ptc['indication_id']==20] = 1\nptc"

# %%
# label.npy
# initialization column 'subject_id'
ptc['subject_id'] = np.arange(1, ptc.shape[0] + 1)
ptc
# Out:
# C:\Users\24700\AppData\Local\Temp\ipykernel_45140\975856318.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ptc['subject_id'] = np.arange(1, ptc.shape[0] + 1)
#      participants_ID   DISC/REP indication formal_status Dataset Consent  \
# 120     sub-87963457  DISCOVERY    BURNOUT       BURNOUT     NaN     YES
# 121     sub-87963593  DISCOVERY    BURNOUT       BURNOUT     NaN     YES
# 122     sub-87963725  DISCOVERY        SMC       UNKNOWN     NaN     YES
# 123     sub-87963769  DISCOVERY        SMC       UNKNOWN     NaN     YES
# 124     sub-87964717  DISCOVERY        SMC       UNKNOWN     NaN     YES
# ...              ...        ...        ...           ...     ...     ...
# 1342    sub-88078657  DISCOVERY   INSOMNIA      INSOMNIA     NaN     YES
# 1343    sub-88078749  DISCOVERY   INSOMNIA      INSOMNIA     NaN     YES
# 1344    sub-88078793  DISCOVERY   INSOMNIA      INSOMNIA     NaN     YES
# 1345    sub-88078837  DISCOVERY   INSOMNIA      INSOMNIA     NaN     YES
# 1346    sub-88079017  DISCOVERY   INSOMNIA      INSOMNIA     NaN     YES
#
#      sessSeason   sessTime Responder Remitter  ... ADHD_pre_Hyp_leading  \
# 120      spring  afternoon       NaN      NaN  ...                  NaN
# 121      spring    morning       NaN      NaN  ...                  NaN
# 122      summer  afternoon       NaN      NaN  ...                  NaN
# 123      summer  afternoon       NaN      NaN  ...                  NaN
# 124      summer  afternoon       NaN      NaN  ...                  NaN
# ...         ...        ...       ...      ...  ...                  ...
# 1342       fall        NaN       NaN      NaN  ...                  NaN
# 1343     winter        NaN       NaN      NaN  ...                  NaN
# 1344     winter        NaN       NaN      NaN  ...                  NaN
# 1345     winter        NaN       NaN      NaN  ...                  NaN
# 1346     winter        NaN       NaN      NaN  ...                  NaN
#
#       ADHD_pre_Att_leading  ADHD_post_Att_leading  ADHD_post_Hyp_leading  \
# 120                    NaN                    NaN                    NaN
# 121                    NaN                    NaN                    NaN
# 122                    NaN                    NaN                    NaN
# 123                    NaN                    NaN                    NaN
# 124                    NaN                    NaN                    NaN
# ...                    ...                    ...                    ...
# 1342                   NaN                    NaN                    NaN
# 1343                   NaN                    NaN                    NaN
# 1344                   NaN                    NaN                    NaN
# 1345                   NaN                    NaN                    NaN
# 1346                   NaN                    NaN                    NaN
#
#       NF Protocol  YBOCS_pre YBOCS_post Unnamed: 110 indication_id subject_id
# 120           NaN        NaN        NaN          NaN             0          1
# 121           NaN        NaN        NaN          NaN             0          2
# 122           NaN        NaN        NaN          NaN             1          3
# 123           NaN        NaN        NaN          NaN             1          4
# 124           NaN        NaN        NaN          NaN             1          5
# ...           ...        ...        ...          ...           ...        ...
# 1342          NaN        NaN        NaN          NaN            57        907
# 1343          NaN        NaN        NaN          NaN            57        908
# 1344          NaN        NaN        NaN          NaN            57        909
# 1345          NaN        NaN        NaN          NaN            57        910
# 1346          NaN        NaN        NaN          NaN            57        911
#
# [911 rows x 113 columns]

# %%
df_label = ptc[['indication_id', 'subject_id']]
label_path = 'Processed/TDBrain-19/Label'
if not os.path.exists(label_path):
    os.makedirs(label_path)
    
np.save(label_path + '/label.npy', df_label.values)

# %%
np.load('Processed/TDBrain-19/Label/label.npy')
# Out:
# array([[  0,   1],
#        [  0,   2],
#        [  1,   3],
#        ...,
#        [ 57, 909],
#        [ 57, 910],
#        [ 57, 911]], dtype=int64)

# %% [markdown]
# ## Features

# %%
# resample the time series data from original_fs to target_fs
def resample_time_series(data, original_fs, target_fs):
    T, C = data.shape
    new_length = int(T * target_fs / original_fs)
    
    resampled_data = np.zeros((new_length, C))
    for i in range(C):
        resampled_data[:, i] = resample(data[:, i], new_length)
        
    return resampled_data

# split the EEG data into segments of length segment_length, dropping the last segment if it is shorter than segment_length
def split_eeg_segments(data, segment_length=128):
    T, C = data.shape
    num_segments = T // segment_length
    reshaped_data = data[:num_segments * segment_length].reshape(num_segments, segment_length, C)

    return reshaped_data

# %%
# 911 valid subjects
# Unified sampling rate: 500Hz
# Unified channels (26 EEG electrodes, 7 additional electrodes). 
# We only use 19 EEG electrodes in 10-20 systems: ['Fp1', 'Fp2', 'F7', 'F3', 'Fz', 'F4', 'F8', 'T3', 'C3', 'Cz', 'C4', 'T4', 'T5', 'P3', 'Pz', 'P4', 'T6', 'O1', 'O2']. 
# T3 and T4 is not in these channels, we use T7 and T8 instead, the two closest electrodes to T3 and T4.
# Initial data downloaded from TDBrain database: All the EEG signals are preprocessed and saved as CSV files
# Data structure: subject-session-task(EC/EO)

feature_path = 'Processed/TDBrain-19/Feature'
if not os.path.exists(feature_path):
    os.makedirs(feature_path)

sub_id = 1
ls_ptc = ptc['participants_ID'].to_list()
for sub in os.listdir(root):
    print(sub)
    print("Effective subject number: ", sub_id)
    # select valid subjects
    if sub in ls_ptc:
        sub_path = os.path.join(root, sub) 
        li_sub = []  # a list to store the EEG data of EO/EC tasks in all sessions of one subject
        for ses in os.listdir(sub_path):
            print(ses)
            print('-----------')
            ses_path = os.path.join(sub_path, ses, 'eeg')
            for task in os.listdir(ses_path):
                if 'EC' in task:
                    print("Eye closed")
                else:
                    print("Eye open")
                task_path = os.path.join(ses_path, task)
                # T7 and T8 is the same position as T3 and T4 
                # P7 and P8 is the same position as T5 and T6
                columns_to_read = ['Fp1', 'Fp2', 'F7', 'F3', 'Fz', 'F4', 'F8', 'T7', 'C3', 'Cz', 'C4', 'T8', 'P7', 'P3', 'Pz', 'P4', 'P8', 'O1', 'O2']
                data = pd.read_csv(task_path, usecols=columns_to_read).to_numpy()
                print("Raw data shape ", data.shape)
                data = resample_time_series(data, 500, SAMPLE_RATE)
                task_array = split_eeg_segments(data, SAMPLE_LEN)
                print("Downsampling and segmented data shape ", task_array.shape)
                li_sub.append(task_array)
                print('--------------------------------------------')
            
        feature_array = np.concatenate(li_sub, axis=0)
        print("Subject array shape ", feature_array.shape)
        np.save(feature_path + '/feature_{:03d}.npy'.format(sub_id), feature_array)
        sub_id += 1
        print('--------------------------------------------------------------------------\n')
    else:
        print(" ", sub, " is not in the list of valid subjects.")
        print('--------------------------------------------------------------------------\n')
        continue
# Out:
# sub-19681349
#   sub-19681349  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19681385
#   sub-19681385  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19684666
#   sub-19684666  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19686324
#   sub-19686324  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19687321
#   sub-19687321  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19687396
#   sub-19687396  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19690494
#   sub-19690494  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19690969
#   sub-19690969  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19691048
#   sub-19691048  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19691782
#   sub-19691782  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19693739
#   sub-19693739  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19694366
#   sub-19694366  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19694625
#   sub-19694625  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19695359
#   sub-19695359  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19696546
#   sub-19696546  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19696870
#   sub-19696870  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19696913
#   sub-19696913  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19697464
#   sub-19697464  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19698310
#   sub-19698310  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19698421
#   sub-19698421  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19698457
#   sub-19698457  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19699415
#   sub-19699415  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19699864
#   sub-19699864  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19700339
#   sub-19700339  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19700415
#   sub-19700415  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19701041
#   sub-19701041  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19701225
#   sub-19701225  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19703032
#   sub-19703032  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19703068
#   sub-19703068  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19703071
#   sub-19703071  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19703366
#   sub-19703366  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19703514
#   sub-19703514  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19703550
#   sub-19703550  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19703697
#   sub-19703697  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19704324
#   sub-19704324  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19704396
#   sub-19704396  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19704914
#   sub-19704914  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19706353
#   sub-19706353  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19708715
#   sub-19708715  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19709895
#   sub-19709895  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19710630
#   sub-19710630  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19710853
#   sub-19710853  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19710961
#   sub-19710961  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19712549
#   sub-19712549  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19712585
#   sub-19712585  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19713254
#   sub-19713254  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19713664
#   sub-19713664  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19713700
#   sub-19713700  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19713736
#   sub-19713736  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19714254
#   sub-19714254  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19714917
#   sub-19714917  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19714953
#   sub-19714953  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19714989
#   sub-19714989  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19715393
#   sub-19715393  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19715724
#   sub-19715724  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19717128
#   sub-19717128  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19717495
#   sub-19717495  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19718014
#   sub-19718014  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19718788
#   sub-19718788  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19718972
#   sub-19718972  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19719273
#   sub-19719273  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19719309
#   sub-19719309  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19720490
#   sub-19720490  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19720635
#   sub-19720635  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19721189
#   sub-19721189  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19721668
#   sub-19721668  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19722259
#   sub-19722259  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19722629
#   sub-19722629  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19722816
#   sub-19722816  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19723112
#   sub-19723112  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19723292
#   sub-19723292  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19723443
#   sub-19723443  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19723479
#   sub-19723479  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19725284
#   sub-19725284  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19725615
#   sub-19725615  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19726317
#   sub-19726317  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19726468
#   sub-19726468  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19726727
#   sub-19726727  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19726872
#   sub-19726872  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19726944
#   sub-19726944  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19727722
#   sub-19727722  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19727830
#   sub-19727830  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19727941
#   sub-19727941  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19729054
#   sub-19729054  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19729349
#   sub-19729349  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19729421
#   sub-19729421  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19730229
#   sub-19730229  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19731853
#   sub-19731853  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19732112
#   sub-19732112  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19732778
#   sub-19732778  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19732850
#   sub-19732850  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19732965
#   sub-19732965  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19733074
#   sub-19733074  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19734252
#   sub-19734252  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19734439
#   sub-19734439  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19734842
#   sub-19734842  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19735246
#   sub-19735246  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19737061
#   sub-19737061  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19737537
#   sub-19737537  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19737911
#   sub-19737911  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19739017
#   sub-19739017  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19739349
#   sub-19739349  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19739424
#   sub-19739424  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19740051
#   sub-19740051  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19740274
#   sub-19740274  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-19741824
#   sub-19741824  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-87963457
# ses-1
# -----------
# Eye closed
# Raw data shape  (60323, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60287, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-87963593
# ses-1
# -----------
# Eye closed
# Raw data shape  (60323, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60323, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-87963725
# ses-1
# -----------
# Eye closed
# Raw data shape  (60323, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60287, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-87963769
# ses-1
# -----------
# Eye closed
# Raw data shape  (60287, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60322, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-87964717
# ses-1
# -----------
# Eye closed
# Raw data shape  (60286, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60322, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# ses-3
# -----------
# Eye closed
# Raw data shape  (60012, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60011, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (480, 128, 19)
# --------------------------------------------------------------------------
#
# sub-87965301
# ses-1
# -----------
# Eye closed
# Raw data shape  (60287, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60287, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-87965393
# ses-1
# -----------
# Eye closed
# Raw data shape  (60323, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60322, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-87965801
# ses-1
# -----------
# Eye closed
# Raw data shape  (60286, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60289, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-87965889
# ses-1
# -----------
# Eye closed
# Raw data shape  (60287, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60287, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-87966249
# ses-1
# -----------
# Eye closed
# Raw data shape  (60323, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60287, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-87966293
# ses-1
# -----------
# Eye closed
# Raw data shape  (60323, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60320, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# ses-2
# -----------
# Eye closed
# Raw data shape  (60287, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60286, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# ses-3
# -----------
# Eye closed
# Raw data shape  (60018, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (59993, 19)
# Downsampling and segmented data shape  (119, 128, 19)
# --------------------------------------------
# Subject array shape  (719, 128, 19)
# --------------------------------------------------------------------------
#
# sub-87966337
# ses-1
# -----------
# Eye closed
# Raw data shape  (60289, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60287, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-87966341
# ses-1
# -----------
# Eye closed
# Raw data shape  (60320, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60287, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-87966385
# ses-1
# -----------
# Eye closed
# Raw data shape  (60287, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60289, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# ses-2
# -----------
# Eye closed
# Raw data shape  (60286, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60289, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (480, 128, 19)
# --------------------------------------------------------------------------
#
# sub-87966429
# ses-1
# -----------
# Eye closed
# Raw data shape  (60287, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60322, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# ses-3
# -----------
# Eye closed
# Raw data shape  (60012, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60018, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (480, 128, 19)
# --------------------------------------------------------------------------
#
# sub-87966473
# ses-1
# -----------
# Eye closed
# Raw data shape  (60323, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60289, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-87966517
# ses-1
# -----------
# Eye closed
# Raw data shape  (60286, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60320, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-87966561
# ses-1
# -----------
# Eye closed
# Raw data shape  (60322, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60287, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# ses-2
# -----------
# Eye closed
# Raw data shape  (60286, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60286, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (480, 128, 19)
# --------------------------------------------------------------------------
#
# sub-87966609
# ses-1
# -----------
# Eye closed
# Raw data shape  (60322, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60320, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-87966701
# ses-1
# -----------
# Eye closed
# Raw data shape  (60289, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60320, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-87966745
# ses-2
# -----------
# Eye closed
# Raw data shape  (60323, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60322, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-87966789
# ses-1
# -----------
# Eye closed
# Raw data shape  (60322, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60286, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-87966877
# ses-1
# -----------
# Eye closed
# Raw data shape  (60323, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60323, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-87966921
# ses-1
# -----------
# Eye closed
# Raw data shape  (60323, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60323, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-87966965
# ses-1
# -----------
# Eye closed
# Raw data shape  (60322, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60320, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-87967013
# ses-1
# -----------
# Eye closed
# Raw data shape  (60323, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60287, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# ses-2
# -----------
# Eye closed
# Raw data shape  (60323, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60322, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (480, 128, 19)
# --------------------------------------------------------------------------
#
# sub-87967057
# ses-1
# -----------
# Eye closed
# Raw data shape  (60320, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60287, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-87967061
# ses-1
# -----------
# Eye closed
# Raw data shape  (60289, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60323, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-87967105
# ses-1
# -----------
# Eye closed
# Raw data shape  (60322, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60287, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# ses-2
# -----------
# Eye closed
# Raw data shape  (60323, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60287, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (480, 128, 19)
# --------------------------------------------------------------------------
#
# sub-87967149
# ses-2
# -----------
# Eye closed
# Raw data shape  (60321, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60321, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-87967281
# ses-1
# -----------
# Eye closed
# Raw data shape  (60287, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60323, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-87967325
# ses-1
# -----------
# Eye closed
# Raw data shape  (60289, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60286, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-87967369
# ses-1
# -----------
# Eye closed
# Raw data shape  (60287, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60286, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# ses-2
# -----------
# Eye closed
# Raw data shape  (60323, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60323, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# ses-3
# -----------
# Eye closed
# Raw data shape  (60011, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60023, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (720, 128, 19)
# --------------------------------------------------------------------------
#
# sub-87967417
# ses-1
# -----------
# Eye closed
# Raw data shape  (60287, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60322, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-87967421
# ses-1
# -----------
# Eye closed
# Raw data shape  (60289, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60323, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-87967509
# ses-1
# -----------
# Eye closed
# Raw data shape  (60287, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60322, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-87967597
# ses-1
# -----------
# Eye closed
# Raw data shape  (60323, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60289, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-87967729
# ses-1
# -----------
# Eye closed
# Raw data shape  (60289, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60287, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-87967773
# ses-1
# -----------
# Eye closed
# Raw data shape  (60289, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60322, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-87967781
# ses-1
# -----------
# Eye closed
# Raw data shape  (60322, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60286, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# ses-3
# -----------
# Eye closed
# Raw data shape  (60017, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60012, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (480, 128, 19)
# --------------------------------------------------------------------------
#
# sub-87967869
# ses-1
# -----------
# Eye closed
# Raw data shape  (60323, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60287, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-87967957
# ses-1
# -----------
# Eye closed
# Raw data shape  (60322, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60322, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-87968001
# ses-1
# -----------
# Eye closed
# Raw data shape  (60287, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60287, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-87968045
# ses-1
# -----------
# Eye closed
# Raw data shape  (60322, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60323, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-87968089
# ses-1
# -----------
# Eye closed
# Raw data shape  (60287, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60323, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-87968133
# ses-1
# -----------
# Eye closed
# Raw data shape  (60323, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60289, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-87968177
# ses-1
# -----------
# Eye closed
# Raw data shape  (60322, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60323, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-87968185
# ses-1
# -----------
# Eye closed
# Raw data shape  (60289, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60287, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-87968229
# ses-1
# -----------
# Eye closed
# Raw data shape  (60286, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60287, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-87968361
# ses-1
# -----------
# Eye closed
# Raw data shape  (60286, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60322, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-87968405
# ses-1
# -----------
# Eye closed
# Raw data shape  (60287, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60322, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-87968449
# ses-1
# -----------
# Eye closed
# Raw data shape  (60323, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60325, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-87968493
# ses-1
# -----------
# Eye closed
# Raw data shape  (60287, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60322, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-87968537
# ses-1
# -----------
# Eye closed
# Raw data shape  (60322, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60322, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-87968541
# ses-1
# -----------
# Eye closed
# Raw data shape  (60322, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60287, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-87968589
# ses-1
# -----------
# Eye closed
# Raw data shape  (60323, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60323, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-87968677
# ses-1
# -----------
# Eye closed
# Raw data shape  (60323, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60286, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-87968721
# ses-1
# -----------
# Eye closed
# Raw data shape  (60287, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60287, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-87968765
# ses-1
# -----------
# Eye closed
# Raw data shape  (60286, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60323, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-87968853
# ses-1
# -----------
# Eye closed
# Raw data shape  (60323, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60286, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-87968897
# ses-1
# -----------
# Eye closed
# Raw data shape  (60286, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60322, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-87968901
# ses-1
# -----------
# Eye closed
# Raw data shape  (60286, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60320, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# ses-2
# -----------
# Eye closed
# Raw data shape  (60286, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60287, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (480, 128, 19)
# --------------------------------------------------------------------------
#
# sub-87968945
# ses-1
# -----------
# Eye closed
# Raw data shape  (60322, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60320, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-87969125
# ses-1
# -----------
# Eye closed
# Raw data shape  (60323, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60323, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# ses-4
# -----------
# Eye closed
# Raw data shape  (60012, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60024, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (480, 128, 19)
# --------------------------------------------------------------------------
#
# sub-87969257
# ses-1
# -----------
# Eye closed
# Raw data shape  (60287, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60322, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-87969305
# ses-1
# -----------
# Eye closed
# Raw data shape  (60322, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60287, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-87969349
# ses-1
# -----------
# Eye closed
# Raw data shape  (60287, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60322, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-87969529
# ses-1
# -----------
# Eye closed
# Raw data shape  (60005, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60018, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# ses-3
# -----------
# Eye closed
# Raw data shape  (60005, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60018, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (480, 128, 19)
# --------------------------------------------------------------------------
#
# sub-87969573
# ses-1
# -----------
# Eye closed
# Raw data shape  (60322, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60322, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# ...
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60008, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-88076225
# ses-1
# -----------
# Eye closed
# Raw data shape  (60006, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60005, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-88076357
# ses-1
# -----------
# Eye closed
# Raw data shape  (60006, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60006, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-88076401
# ses-1
# -----------
# Eye closed
# Raw data shape  (60006, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60006, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-88076445
# ses-1
# -----------
# Eye closed
# Raw data shape  (60006, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60005, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-88076489
# ses-1
# -----------
# Eye closed
# Raw data shape  (60009, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60006, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-88076577
# ses-1
# -----------
# Eye closed
# Raw data shape  (60006, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60006, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-88076629
# ses-1
# -----------
# Eye closed
# Raw data shape  (60006, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60006, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-88076717
# ses-1
# -----------
# Eye closed
# Raw data shape  (60008, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60008, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-88076761
# ses-1
# -----------
# Eye closed
# Raw data shape  (60008, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60008, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-88076805
# ses-1
# -----------
# Eye closed
# Raw data shape  (60012, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60006, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-88076849
# ses-1
# -----------
# Eye closed
# Raw data shape  (60005, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60008, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-88076941
# ses-1
# -----------
# Eye closed
# Raw data shape  (60008, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60006, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-88076989
# ses-1
# -----------
# Eye closed
# Raw data shape  (60008, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60008, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-88077077
# ses-1
# -----------
# Eye closed
# Raw data shape  (60006, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60009, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-88077209
# ses-1
# -----------
# Eye closed
# Raw data shape  (60009, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60009, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-88077253
#   sub-88077253  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-88077301
#   sub-88077301  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# sub-88077345
# ses-1
# -----------
# Eye closed
# Raw data shape  (60002, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60008, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-88077393
# ses-1
# -----------
# Eye closed
# Raw data shape  (60006, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60009, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-88077525
# ses-1
# -----------
# Eye closed
# Raw data shape  (60008, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60006, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-88077569
# ses-1
# -----------
# Eye closed
# Raw data shape  (60008, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60006, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-88077613
# ses-1
# -----------
# Eye closed
# Raw data shape  (60008, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60006, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-88077657
# ses-1
# -----------
# Eye closed
# Raw data shape  (60006, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60008, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-88077705
# ses-1
# -----------
# Eye closed
# Raw data shape  (60008, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60012, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-88078161
# ses-1
# -----------
# Eye closed
# Raw data shape  (60005, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60006, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-88078253
# ses-1
# -----------
# Eye closed
# Raw data shape  (60006, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60006, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-88078297
# ses-1
# -----------
# Eye closed
# Raw data shape  (60009, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60008, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-88078301
# ses-1
# -----------
# Eye closed
# Raw data shape  (60006, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60008, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-88078433
# ses-1
# -----------
# Eye closed
# Raw data shape  (60009, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60008, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-88078477
# ses-1
# -----------
# Eye closed
# Raw data shape  (60006, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60006, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-88078521
# ses-1
# -----------
# Eye closed
# Raw data shape  (60008, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60006, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-88078565
# ses-1
# -----------
# Eye closed
# Raw data shape  (60006, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60006, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-88078613
# ses-1
# -----------
# Eye closed
# Raw data shape  (60008, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60006, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-88078657
# ses-1
# -----------
# Eye closed
# Raw data shape  (60008, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60008, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-88078749
# ses-1
# -----------
# Eye closed
# Raw data shape  (60006, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60006, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-88078793
# ses-1
# -----------
# Eye closed
# Raw data shape  (60006, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60008, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-88078837
# ses-1
# -----------
# Eye closed
# Raw data shape  (60006, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60006, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# sub-88079017
# ses-1
# -----------
# Eye closed
# Raw data shape  (60008, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Eye open
# Raw data shape  (60005, 19)
# Downsampling and segmented data shape  (120, 128, 19)
# --------------------------------------------
# Subject array shape  (240, 128, 19)
# --------------------------------------------------------------------------
#
# TDBRAIN_participants_V2.tsv
#   TDBRAIN_participants_V2.tsv  is not in the list of valid subjects.
# --------------------------------------------------------------------------
#
# TDBRAIN_participants_V2.xlsx
#   TDBRAIN_participants_V2.xlsx  is not in the list of valid subjects.
# --------------------------------------------------------------------------

# %%
# Test the saved npy file
# example
np.load('Processed/TDBrain-19/Feature/feature_016.npy').shape
# Out:
# (240, 128, 19)
