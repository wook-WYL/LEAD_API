# %%
import os
import mne
import numpy as np
import pandas as pd
from scipy.signal import resample
import warnings
warnings.filterwarnings("ignore")

# %%
SAMPLE_RATE = 128  # fs
SAMPLE_LEN = 128   # T

# %%
# root dir
root = 'ADFTD/'
# participants file path
participants_path = os.path.join(root, 'participants.tsv')
participants = pd.read_csv(participants_path, sep='\t')
participants
# Out:
#    participant_id Gender  Age Group  MMSE
# 0         sub-001      F   57     A    16
# 1         sub-002      F   78     A    22
# 2         sub-003      M   70     A    14
# 3         sub-004      F   67     A    20
# 4         sub-005      M   70     A    22
# ..            ...    ...  ...   ...   ...
# 83        sub-084      F   71     F    24
# 84        sub-085      M   64     F    26
# 85        sub-086      M   49     F    26
# 86        sub-087      M   73     F    24
# 87        sub-088      M   55     F    24
#
# [88 rows x 5 columns]

# %% [markdown]
# ## Labels

# %%
labels = np.empty(shape=(participants.shape[0],2), dtype='int32')
labels.shape
# Out:
# (88, 2)

# %%
label_map = {'A':2, 'F':1, 'C':0}
for i, participant in enumerate(participants.values):
    # print(participant)
    pid = int(participant[0][-3:])
    label = label_map[participant[3]]
    # print(pid)
    # print(label)
    labels[i,0] = label
    labels[i,1] = pid

# %%
label_path = 'Processed/ADFTD/Label'
if not os.path.exists(label_path):
    os.makedirs(label_path)
np.save(label_path + '/label.npy', labels)

# %%
np.load('Processed/ADFTD/Label/label.npy')
# Out:
# array([[ 2,  1],
#        [ 2,  2],
#        [ 2,  3],
#        [ 2,  4],
#        [ 2,  5],
#        [ 2,  6],
#        [ 2,  7],
#        [ 2,  8],
#        [ 2,  9],
#        [ 2, 10],
#        [ 2, 11],
#        [ 2, 12],
#        [ 2, 13],
#        [ 2, 14],
#        [ 2, 15],
#        [ 2, 16],
#        [ 2, 17],
#        [ 2, 18],
#        [ 2, 19],
#        [ 2, 20],
#        [ 2, 21],
#        [ 2, 22],
#        [ 2, 23],
#        [ 2, 24],
#        [ 2, 25],
#        [ 2, 26],
#        [ 2, 27],
#        [ 2, 28],
#        [ 2, 29],
#        [ 2, 30],
#        [ 2, 31],
#        [ 2, 32],
#        [ 2, 33],
#        [ 2, 34],
#        [ 2, 35],
#        [ 2, 36],
#        [ 0, 37],
#        [ 0, 38],
#        [ 0, 39],
#        [ 0, 40],
#        [ 0, 41],
#        [ 0, 42],
#        [ 0, 43],
#        [ 0, 44],
#        [ 0, 45],
#        [ 0, 46],
#        [ 0, 47],
#        [ 0, 48],
#        [ 0, 49],
#        [ 0, 50],
#        [ 0, 51],
#        [ 0, 52],
#        [ 0, 53],
#        [ 0, 54],
#        [ 0, 55],
#        [ 0, 56],
#        [ 0, 57],
#        [ 0, 58],
#        [ 0, 59],
#        [ 0, 60],
#        [ 0, 61],
#        [ 0, 62],
#        [ 0, 63],
#        [ 0, 64],
#        [ 0, 65],
#        [ 1, 66],
#        [ 1, 67],
#        [ 1, 68],
#        [ 1, 69],
#        [ 1, 70],
#        [ 1, 71],
#        [ 1, 72],
#        [ 1, 73],
#        [ 1, 74],
#        [ 1, 75],
#        [ 1, 76],
#        [ 1, 77],
#        [ 1, 78],
#        [ 1, 79],
#        [ 1, 80],
#        [ 1, 81],
#        [ 1, 82],
#        [ 1, 83],
#        [ 1, 84],
#        [ 1, 85],
#        [ 1, 86],
#        [ 1, 87],
#        [ 1, 88]])

# %% [markdown]
# ## Features

# %%
derivatives_root = os.path.join(root, 'derivatives/')
derivatives_root
# Out:
# 'ADFTD/derivatives/'

# %%
# Test for bad channels, sampling freq and shape
bad_channel_list, sampling_freq_list, data_shape_list = [], [], []
for sub in os.listdir(derivatives_root):
    if 'sub-' in sub:
        sub_path = os.path.join(derivatives_root, sub, 'eeg/')
        # print(sub_path)
        for file in os.listdir(sub_path):
            if '.set' in file:
                file_path = os.path.join(sub_path, file)
                raw = mne.io.read_raw_eeglab(file_path, preload=True)
                # get bad channels
                bad_channel = raw.info['bads']
                bad_channel_list.append(bad_channel)
                # get sampling frequency
                sampling_freq = raw.info['sfreq']
                sampling_freq_list.append(sampling_freq)
                # get eeg data
                data = raw.get_data()
                data_shape = data.shape
                data_shape_list.append(data_shape)

# %%
# 0 bad channels
print(bad_channel_list)
# 500 Hz for all runs
print(sampling_freq_list)
# same number of channels & different timestamps
print(data_shape_list)
# Out:
# [[], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]
# [500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0, 500.0]
# [(19, 299900), (19, 396550), (19, 153050), (19, 353050), (19, 402050), (19, 316200), (19, 383210), (19, 396700), (19, 306300), (19, 640860), (19, 384960), (19, 441760), (19, 419050), (19, 467220), (19, 450690), (19, 486180), (19, 421700), (19, 422550), (19, 459310), (19, 434650), (19, 460140), (19, 410960), (19, 417370), (19, 379900), (19, 342180), (19, 449320), (19, 413100), (19, 409070), (19, 368340), (19, 277040), (19, 575380), (19, 398890), (19, 352710), (19, 484950), (19, 370520), (19, 420680), (19, 388550), (19, 445700), (19, 425040), (19, 482870), (19, 443050), (19, 481510), (19, 414550), (19, 440800), (19, 425820), (19, 376520), (19, 403500), (19, 494940), (19, 390100), (19, 408820), (19, 376670), (19, 380050), (19, 390260), (19, 418810), (19, 407300), (19, 395660), (19, 398250), (19, 378390), (19, 393560), (19, 374240), (19, 401640), (19, 449350), (19, 402470), (19, 424050), (19, 442050), (19, 274880), (19, 321550), (19, 286550), (19, 318050), (19, 239550), (19, 309450), (19, 328710), (19, 427290), (19, 507250), (19, 374090), (19, 409400), (19, 349570), (19, 435450), (19, 408340), (19, 457570), (19, 412240), (19, 388800), (19, 456600), (19, 326050), (19, 280030), (19, 289400), (19, 301380), (19, 392350)]

# %%
# resample the time series data from original_fs to target_fs
def resample_time_series(data, original_fs, target_fs):
    T, C = data.shape
    new_length = int(T * target_fs / original_fs)

    resampled_data = np.zeros((new_length, C))
    for i in range(C):
        resampled_data[:, i] = resample(data[:, i], new_length)

    return resampled_data

# split the EEG data into segments of length segment_length, dropping the last segment if it is shorter than segment_length
def split_eeg_segments(data, segment_length=128):
    T, C = data.shape
    num_segments = T // segment_length
    reshaped_data = data[:num_segments * segment_length].reshape(num_segments, segment_length, C)

    return reshaped_data

# %%
feature_path = 'Processed/ADFTD/Feature'
if not os.path.exists(feature_path):
    os.makedirs(feature_path)

sub_id = 1
for sub in os.listdir(derivatives_root):
    if 'sub-' in sub:
        li_sub = []
        sub_path = os.path.join(derivatives_root, sub, 'eeg/')
        print(sub_path)
        for file in os.listdir(sub_path):
            if '.set' in file:
                file_path = os.path.join(sub_path, file)
                raw = mne.io.read_raw_eeglab(file_path, preload=True)
                data = raw.get_data().T
                print("Raw data shape ", data.shape)
                data = resample_time_series(data, 500, SAMPLE_RATE)
                feature_array = split_eeg_segments(data, SAMPLE_LEN)
                print("Downsampling and segmented data shape ", feature_array.shape)
                np.save(feature_path + '/feature_{:02d}.npy'.format(sub_id), feature_array)
        sub_id += 1
    print("-------------------------------------\n")
# Out:
# ADFTD/derivatives/sub-001\eeg/
# Raw data shape  (299900, 19)
# Downsampling and segmented data shape  (149, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-002\eeg/
# Raw data shape  (396550, 19)
# Downsampling and segmented data shape  (198, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-003\eeg/
# Raw data shape  (153050, 19)
# Downsampling and segmented data shape  (76, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-004\eeg/
# Raw data shape  (353050, 19)
# Downsampling and segmented data shape  (176, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-005\eeg/
# Raw data shape  (402050, 19)
# Downsampling and segmented data shape  (201, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-006\eeg/
# Raw data shape  (316200, 19)
# Downsampling and segmented data shape  (158, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-007\eeg/
# Raw data shape  (383210, 19)
# Downsampling and segmented data shape  (191, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-008\eeg/
# Raw data shape  (396700, 19)
# Downsampling and segmented data shape  (198, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-009\eeg/
# Raw data shape  (306300, 19)
# Downsampling and segmented data shape  (153, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-010\eeg/
# Raw data shape  (640860, 19)
# Downsampling and segmented data shape  (320, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-011\eeg/
# Raw data shape  (384960, 19)
# Downsampling and segmented data shape  (192, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-012\eeg/
# Raw data shape  (441760, 19)
# Downsampling and segmented data shape  (220, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-013\eeg/
# Raw data shape  (419050, 19)
# Downsampling and segmented data shape  (209, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-014\eeg/
# Raw data shape  (467220, 19)
# Downsampling and segmented data shape  (233, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-015\eeg/
# Raw data shape  (450690, 19)
# Downsampling and segmented data shape  (225, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-016\eeg/
# Raw data shape  (486180, 19)
# Downsampling and segmented data shape  (243, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-017\eeg/
# Raw data shape  (421700, 19)
# Downsampling and segmented data shape  (210, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-018\eeg/
# Raw data shape  (422550, 19)
# Downsampling and segmented data shape  (211, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-019\eeg/
# Raw data shape  (459310, 19)
# Downsampling and segmented data shape  (229, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-020\eeg/
# Raw data shape  (434650, 19)
# Downsampling and segmented data shape  (217, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-021\eeg/
# Raw data shape  (460140, 19)
# Downsampling and segmented data shape  (230, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-022\eeg/
# Raw data shape  (410960, 19)
# Downsampling and segmented data shape  (205, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-023\eeg/
# Raw data shape  (417370, 19)
# Downsampling and segmented data shape  (208, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-024\eeg/
# Raw data shape  (379900, 19)
# Downsampling and segmented data shape  (189, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-025\eeg/
# Raw data shape  (342180, 19)
# Downsampling and segmented data shape  (171, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-026\eeg/
# Raw data shape  (449320, 19)
# Downsampling and segmented data shape  (224, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-027\eeg/
# Raw data shape  (413100, 19)
# Downsampling and segmented data shape  (206, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-028\eeg/
# Raw data shape  (409070, 19)
# Downsampling and segmented data shape  (204, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-029\eeg/
# Raw data shape  (368340, 19)
# Downsampling and segmented data shape  (184, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-030\eeg/
# Raw data shape  (277040, 19)
# Downsampling and segmented data shape  (138, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-031\eeg/
# Raw data shape  (575380, 19)
# Downsampling and segmented data shape  (287, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-032\eeg/
# Raw data shape  (398890, 19)
# Downsampling and segmented data shape  (199, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-033\eeg/
# Raw data shape  (352710, 19)
# Downsampling and segmented data shape  (176, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-034\eeg/
# Raw data shape  (484950, 19)
# Downsampling and segmented data shape  (242, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-035\eeg/
# Raw data shape  (370520, 19)
# Downsampling and segmented data shape  (185, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-036\eeg/
# Raw data shape  (420680, 19)
# Downsampling and segmented data shape  (210, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-037\eeg/
# Raw data shape  (388550, 19)
# Downsampling and segmented data shape  (194, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-038\eeg/
# Raw data shape  (445700, 19)
# Downsampling and segmented data shape  (222, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-039\eeg/
# Raw data shape  (425040, 19)
# Downsampling and segmented data shape  (212, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-040\eeg/
# Raw data shape  (482870, 19)
# Downsampling and segmented data shape  (241, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-041\eeg/
# Raw data shape  (443050, 19)
# Downsampling and segmented data shape  (221, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-042\eeg/
# Raw data shape  (481510, 19)
# Downsampling and segmented data shape  (240, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-043\eeg/
# Raw data shape  (414550, 19)
# Downsampling and segmented data shape  (207, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-044\eeg/
# Raw data shape  (440800, 19)
# Downsampling and segmented data shape  (220, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-045\eeg/
# Raw data shape  (425820, 19)
# Downsampling and segmented data shape  (212, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-046\eeg/
# Raw data shape  (376520, 19)
# Downsampling and segmented data shape  (188, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-047\eeg/
# Raw data shape  (403500, 19)
# Downsampling and segmented data shape  (201, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-048\eeg/
# Raw data shape  (494940, 19)
# Downsampling and segmented data shape  (247, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-049\eeg/
# Raw data shape  (390100, 19)
# Downsampling and segmented data shape  (195, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-050\eeg/
# Raw data shape  (408820, 19)
# Downsampling and segmented data shape  (204, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-051\eeg/
# Raw data shape  (376670, 19)
# Downsampling and segmented data shape  (188, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-052\eeg/
# Raw data shape  (380050, 19)
# Downsampling and segmented data shape  (190, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-053\eeg/
# Raw data shape  (390260, 19)
# Downsampling and segmented data shape  (195, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-054\eeg/
# Raw data shape  (418810, 19)
# Downsampling and segmented data shape  (209, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-055\eeg/
# Raw data shape  (407300, 19)
# Downsampling and segmented data shape  (203, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-056\eeg/
# Raw data shape  (395660, 19)
# Downsampling and segmented data shape  (197, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-057\eeg/
# Raw data shape  (398250, 19)
# Downsampling and segmented data shape  (199, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-058\eeg/
# Raw data shape  (378390, 19)
# Downsampling and segmented data shape  (189, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-059\eeg/
# Raw data shape  (393560, 19)
# Downsampling and segmented data shape  (196, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-060\eeg/
# Raw data shape  (374240, 19)
# Downsampling and segmented data shape  (187, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-061\eeg/
# Raw data shape  (401640, 19)
# Downsampling and segmented data shape  (200, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-062\eeg/
# Raw data shape  (449350, 19)
# Downsampling and segmented data shape  (224, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-063\eeg/
# Raw data shape  (402470, 19)
# Downsampling and segmented data shape  (201, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-064\eeg/
# Raw data shape  (424050, 19)
# Downsampling and segmented data shape  (212, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-065\eeg/
# Raw data shape  (442050, 19)
# Downsampling and segmented data shape  (221, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-066\eeg/
# Raw data shape  (274880, 19)
# Downsampling and segmented data shape  (137, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-067\eeg/
# Raw data shape  (321550, 19)
# Downsampling and segmented data shape  (160, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-068\eeg/
# Raw data shape  (286550, 19)
# Downsampling and segmented data shape  (143, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-069\eeg/
# Raw data shape  (318050, 19)
# Downsampling and segmented data shape  (159, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-070\eeg/
# Raw data shape  (239550, 19)
# Downsampling and segmented data shape  (119, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-071\eeg/
# Raw data shape  (309450, 19)
# Downsampling and segmented data shape  (154, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-072\eeg/
# Raw data shape  (328710, 19)
# Downsampling and segmented data shape  (164, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-073\eeg/
# Raw data shape  (427290, 19)
# Downsampling and segmented data shape  (213, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-074\eeg/
# Raw data shape  (507250, 19)
# Downsampling and segmented data shape  (253, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-075\eeg/
# Raw data shape  (374090, 19)
# Downsampling and segmented data shape  (187, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-076\eeg/
# Raw data shape  (409400, 19)
# Downsampling and segmented data shape  (204, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-077\eeg/
# Raw data shape  (349570, 19)
# Downsampling and segmented data shape  (174, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-078\eeg/
# Raw data shape  (435450, 19)
# Downsampling and segmented data shape  (217, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-079\eeg/
# Raw data shape  (408340, 19)
# Downsampling and segmented data shape  (204, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-080\eeg/
# Raw data shape  (457570, 19)
# Downsampling and segmented data shape  (228, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-081\eeg/
# Raw data shape  (412240, 19)
# Downsampling and segmented data shape  (206, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-082\eeg/
# Raw data shape  (388800, 19)
# Downsampling and segmented data shape  (194, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-083\eeg/
# Raw data shape  (456600, 19)
# Downsampling and segmented data shape  (228, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-084\eeg/
# Raw data shape  (326050, 19)
# Downsampling and segmented data shape  (163, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-085\eeg/
# Raw data shape  (280030, 19)
# Downsampling and segmented data shape  (140, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-086\eeg/
# Raw data shape  (289400, 19)
# Downsampling and segmented data shape  (144, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-087\eeg/
# Raw data shape  (301380, 19)
# Downsampling and segmented data shape  (150, 1024, 19)
# -------------------------------------
#
# ADFTD/derivatives/sub-088\eeg/
# Raw data shape  (392350, 19)
# Downsampling and segmented data shape  (196, 1024, 19)
# -------------------------------------

# %%
# Test the saved npy file
# example

path = 'Processed/ADFTD/Feature/'

for file in os.listdir(path):
    sub_path = os.path.join(path, file)
    print(np.load(sub_path).shape)
# Out:
# (149, 1024, 19)
# (198, 1024, 19)
# (76, 1024, 19)
# (176, 1024, 19)
# (201, 1024, 19)
# (158, 1024, 19)
# (191, 1024, 19)
# (198, 1024, 19)
# (153, 1024, 19)
# (320, 1024, 19)
# (192, 1024, 19)
# (220, 1024, 19)
# (209, 1024, 19)
# (233, 1024, 19)
# (225, 1024, 19)
# (243, 1024, 19)
# (210, 1024, 19)
# (211, 1024, 19)
# (229, 1024, 19)
# (217, 1024, 19)
# (230, 1024, 19)
# (205, 1024, 19)
# (208, 1024, 19)
# (189, 1024, 19)
# (171, 1024, 19)
# (224, 1024, 19)
# (206, 1024, 19)
# (204, 1024, 19)
# (184, 1024, 19)
# (138, 1024, 19)
# (287, 1024, 19)
# (199, 1024, 19)
# (176, 1024, 19)
# (242, 1024, 19)
# (185, 1024, 19)
# (210, 1024, 19)
# (194, 1024, 19)
# (222, 1024, 19)
# (212, 1024, 19)
# (241, 1024, 19)
# (221, 1024, 19)
# (240, 1024, 19)
# (207, 1024, 19)
# (220, 1024, 19)
# (212, 1024, 19)
# (188, 1024, 19)
# (201, 1024, 19)
# (247, 1024, 19)
# (195, 1024, 19)
# (204, 1024, 19)
# (188, 1024, 19)
# (190, 1024, 19)
# (195, 1024, 19)
# (209, 1024, 19)
# (203, 1024, 19)
# (197, 1024, 19)
# (199, 1024, 19)
# (189, 1024, 19)
# (196, 1024, 19)
# (187, 1024, 19)
# (200, 1024, 19)
# (224, 1024, 19)
# (201, 1024, 19)
# (212, 1024, 19)
# (221, 1024, 19)
# (137, 1024, 19)
# (160, 1024, 19)
# (143, 1024, 19)
# (159, 1024, 19)
# (119, 1024, 19)
# (154, 1024, 19)
# (164, 1024, 19)
# (213, 1024, 19)
# (253, 1024, 19)
# (187, 1024, 19)
# (204, 1024, 19)
# (174, 1024, 19)
# (217, 1024, 19)
# (204, 1024, 19)
# (228, 1024, 19)
# (206, 1024, 19)
# (194, 1024, 19)
# (228, 1024, 19)
# (163, 1024, 19)
# (140, 1024, 19)
# (144, 1024, 19)
# (150, 1024, 19)
# (196, 1024, 19)
